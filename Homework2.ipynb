# %% [markdown]
# <a href="https://colab.research.google.com/github/lmaymir/AI-in-BMEN/blob/main/Homework2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework 2
# ## BMEN 6367
# ## Luke Maymir

# %%
# Mouning Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Importing libraries
from skimage import io, exposure, feature, color
import matplotlib.pyplot as plt
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Creating function to display an input image and that image's histogram
def img_hist(im):
  # Show image
  plt.imshow(im)
  plt.axis('off')
  plt.show()

  # Show histogram
  img_hist, bins = exposure.histogram(im)
  plt.bar(bins, img_hist)
  plt.show()

# Loading image from Google Drive
img = io.imread('/content/drive/MyDrive/Schoolwork/BMEN 6367/Homework 2/temoc-profile.jpg')
img_hist(img)

# Equalizing that image's histogram
img_eq = exposure.equalize_hist(img)
img_hist(img_eq)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
# /usr/local/lib/python3.7/dist-packages/skimage/exposure/exposure.py:181: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
#   hist, bin_centers = histogram(image, nbins)

# %%
# Loading another image from Google Drive
img = io.imread('/content/drive/MyDrive/Schoolwork/BMEN 6367/Homework 2/dallas-skyline.jpg')
img = color.rgb2gray(img) # Convering image to grayscale
plt.imshow(img) # Showing image
plt.axis('off')
plt.show()

# Performing edge detection on image
img_edge = feature.canny(img, sigma=2.8)
plt.imshow(img_edge) # Showing detected edges
plt.axis('off')
plt.show()
